# %%
import chess
import random

#read from file
f = open("all_moves_proba.txt", "r")
all_moves = {a:int(b) for a,b in [line.split(",") for line in f]}
print(len(all_moves))
# Out:
# 16002

# %%
def simulate_game():
    seen_moves = set()
    board = chess.Board()
    print(board)
    i=0
    while not board.is_game_over():     
        i+=1 
        for move in board.legal_moves:
            seen_moves.add(board.san(move))
        board.push(random.choice(list(board.legal_moves)))
    print(i)
    return seen_moves

# generate random games and fetch all moves seen

for i in range(10000):
        seen_moves =simulate_game()
        for move in seen_moves:
            if move in all_moves:
                all_moves[move]+=1
            else:
                all_moves[move]=1
        print(len(all_moves))

print(all_moves)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 425
# 16002
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 113
# 16002
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 505
# 16002
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 425
# 16002
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 366
# 16002
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 522
# 16002
# r n b q k b n r
# p p p p p p p p
# ...

# %%
with open("all_moves_proba.txt", "w") as f:
    for val in all_moves:
        f.write(val+","+str(all_moves[val])+"\n")

# %%
# save all moves to a file
# with open("all_moves.txt", "w") as f:
#     for move in all_moves:
#         f.write(str(move) + "\n")

# %%
longest = ""
for move in all_moves:
    if len(move) > len(longest):
        longest = move

print(longest)
# Out:
# exf8=Q#
